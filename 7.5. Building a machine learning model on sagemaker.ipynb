# %% [markdown]
# ## Steps to build and deploy the cardiac arrest predictor
#
# 1. Loading and pre-processing the data
# 2. Transferring the pre-processed data on Amazon bucket
# 3. Defining and training the model
# 4. Deploying the model

# %% [markdown]
# ### 1. Loading and pre-processing the data

# %%
# import libraries
import numpy as np
import pandas as pd

# %%
# reading the data
data = pd.read_csv('./Cardiac_arrest_data.csv')

# first 5 rows of the data
data.head()
# Out:
#    Gender  Height  Weight Smoke Alcohol Cardio
# 0    Male     168    62.0    No      No     No
# 1  Female     156    85.0    No      No    Yes
# 2  Female     165    64.0    No      No    Yes
# 3    Male     169    82.0    No      No    Yes
# 4  Female     156    56.0    No      No     No

# %%
# converting categories into numbers
data['Gender']= data['Gender'].map({'Male':0, 'Female':1})
data['Smoke']= data['Smoke'].map({'No':0, 'Yes':1})
data['Alcohol']= data['Alcohol'].map({'No':0, 'Yes':1})
data['Cardio']= data['Cardio'].map({'No':0, 'Yes':1})

# %%
# creating train and test data
from sklearn.model_selection import train_test_split
train, test = train_test_split(data, test_size = 0.3, random_state = 10)
print(train.shape, test.shape)
# Out:
# (49000, 6) (21000, 6)

# %% [markdown]
# ### 2. Transferring the pre-processed data on Amazon S3 bucket

# %%
# specify bucket name
bucket_name = 'cardiac-arrest-predictor'

# %% [markdown]
# NOTE: target variable has to be the first column in the training and validation datasets

# %%
# creating the training set for sagemaker
pd.concat([train['Cardio'], train.drop(['Cardio'], axis=1)], axis=1).to_csv('train.csv', index=False, header=False)

# %%
# importing libraries for sagemaker
import boto3, sagemaker

# %%
# storing the training set in s3 bucket
boto3.Session().resource('s3').Bucket(bucket_name).Object('train/train.csv').upload_file('train.csv')

# %% [markdown]
# ### 3. Defining and training the model

# %%
# defining the training set for sagemaker
s3_input_train = sagemaker.inputs.TrainingInput(s3_data='s3://{}/train'.format(bucket_name), content_type='csv')

# %%
# set the region of the instance
my_region = boto3.session.Session().region_name
my_region
# Out:
# 'ap-south-1'

# %%
# defining the xgboost container
from sagemaker import image_uris
xgboost_container = image_uris.retrieve(framework = 'xgboost', region = my_region, version = '1.2-1')

# %%
# defining the hyperparameters for xgboost algorithm
hyperparameters = {
        "max_depth":"5",
        "eta":"0.2",
        "gamma":"4",
        "min_child_weight":"6",
        "subsample":"0.7",
        "objective":"binary:logistic",
        "num_round":"50"}

# %%
# Define IAM role (Identity and Access Management)
from sagemaker import get_execution_role
role = get_execution_role()

# %%
# defining the machine learning model
estimator = sagemaker.estimator.Estimator(image_uri=xgboost_container, 
                                          hyperparameters=hyperparameters,
                                          role=role,
                                          instance_count=1, 
                                          instance_type='ml.m4.xlarge', 
                                          volume_size=1,
                                          output_path='s3://{}/output'.format(bucket_name))

# %%
# training the model
estimator.fit({'train': s3_input_train})
# Out:
# 2021-03-08 14:13:26 Starting - Starting the training job...
# 2021-03-08 14:13:29 Starting - Launching requested ML instancesProfilerReport-1615212806: InProgress
# ......
# 2021-03-08 14:14:40 Starting - Preparing the instances for training.........
# 2021-03-08 14:16:21 Downloading - Downloading input data
# 2021-03-08 14:16:21 Training - Downloading the training image.....[2021-03-08 14:17:04.102 ip-10-0-88-156.ap-south-1.compute.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# INFO:root:Train matrix has 49000 rows
# [0]#011train-error:0.41514
# [1]#011train-error:0.41514
# [2]#011train-error:0.41557
# [3]#011train-error:0.41445
# [4]#011train-error:0.41371
# [5]#011train-error:0.41402
# [6]#011train-error:0.41269
# [7]#011train-error:0.41216
# [8]#011train-error:0.41386
# [9]#011train-error:0.41449
# [10]#011train-error:0.41347
# [11]#011train-error:0.41384
# [12]#011train-error:0.41382
# [13]#011train-error:0.41355
# [14]#011train-error:0.41351
# [15]#011train-error:0.41318
# [16]#011train-error:0.41300
# [17]#011train-error:0.41300
# [18]#011train-error:0.41314
# [19]#011train-error:0.41314
# [20]#011train-error:0.41320
# [21]#011train-error:0.41318
# [22]#011train-error:0.41292
# [23]#011train-error:0.41298
# [24]#011train-error:0.41298
# [25]#011train-error:0.41296
# [26]#011train-error:0.41271
# [27]#011train-error:0.41302
# [28]#011train-error:0.41292
# [29]#011train-error:0.41275
# [30]#011train-error:0.41290
# [31]#011train-error:0.41292
# [32]#011train-error:0.41271
# [33]#011train-error:0.41274
# [34]#011train-error:0.41271
# [35]#011train-error:0.41271
# [36]#011train-error:0.41261
# [37]#011train-error:0.41259
# [38]#011train-error:0.41265
# [39]#011train-error:0.41274
# [40]#011train-error:0.41220
# [41]#011train-error:0.41218
# [42]#011train-error:0.41182
# [43]#011train-error:0.41175
# [44]#011train-error:0.41175
# [45]#011train-error:0.41194
# [46]#011train-error:0.41198
# [47]#011train-error:0.41200
# [48]#011train-error:0.41200
# [49]#011train-error:0.41196
#
# 2021-03-08 14:17:22 Uploading - Uploading generated training model
# 2021-03-08 14:17:44 Completed - Training job completed
# Training seconds: 106
# Billable seconds: 106

# %% [markdown]
# ### 4. Deploying the model

# %%
# defining serializer
from sagemaker.serializers import CSVSerializer

# %%
# deploying the model on sagemaker
xgb_predictor = estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge', serializer=CSVSerializer())
# Out:
# ---------------!

# %%
# converting the data into an array
test_data_array = test.drop(['Cardio'], axis=1).values

# generating predictions
predictions = xgb_predictor.predict(test_data_array)

predictions
# Out:
# b'0.6073262095451355,0.5173147320747375,0.3424641788005829,0.45691725611686707,0.5105768442153931,0.41609349846839905,0.7107326984405518,0.4658510684967041,0.35433053970336914,0.5108885169029236,0.5740941762924194,0.43859389424324036,0.44286635518074036,0.44286635518074036,0.3700127899646759,0.45618247985839844,0.5083429217338562,0.39742618799209595,0.5818092823028564,0.45762142539024353,0.4340724050998688,0.6839481592178345,0.5108885169029236,0.44286635518074036,0.5527456402778625,0.5059058666229248,0.5999979972839355,0.40653273463249207,0.6083126068115234,0.659843921661377,0.2358853667974472,0.46616652607917786,0.42941024899482727,0.513866662979126,0.7049894332885742,0.4671017825603485,0.5343353152275085,0.7101582288742065,0.5428138971328735,0.6308749318122864,0.6886477470397949,0.45116832852363586,0.5533838272094727,0.5737374424934387,0.48070836067199707,0.5170656442642212,0.38194456696510315,0.537693202495575,0.5257443189620972,0.45437097549438477,0.3975895345211029,0.6474557518959045,0.44286635518074036,0.5450772643089294,0.5200209617614746,0.4817052483558655,0.4978432059288025,0.6485293507575989,0.5769911408424377,0.5374173521995544,0.4477907717227936,0.34014469385147095,0.4340724050998688,0.4782250225543976,0.5392434597015381,0.38834163546562195,0.5136762261390686,0.5568506717681885,0.6320708990097046,0.5148910284042358,0.45762142539024353,0.6305272579193115,0.29116278886795044,0.5364747047424316,0.4714978039264679,0.5939849019050598,0.5018321871757507,0.4629081189632416,0.5178843140602112,0.5257443189620972,0.26166924834251404,0.5056440234184265,0.5108885169029236,0.44782787561416626,0.5780494213104248,0.6632168292999268,0.41609349846839905,0.41856321692466736,0.5089489817619324,0.6246867179870605,0.5779045224189758,0.5983713269233704,0.4189659357070923,0.5779045224189758,0.538076639175415,0.3367674648761749,0.7479433417320251,0.5750293731689453,0.6180236339569092,0.4446621239185333,0.5533401966094971,0.6835327744483948,0.4596596360206604,0.39366021752357483,0.4782250225543976,0.4624343812465668,0.45437097549438477,0.6350822448730469,0.6190560460090637,0.5112307667732239,0.5170494318008423,0.4340724050998688,0.4896650016307831,0.4516632556915283,0.4340724050998688,0.6478223204612732,0.4678286910057068,0.5655985474586487,0.34571874141693115,0.4984310269355774,0.4105627238750458,0.4940396249294281,0.46301329135894775,0.5723685622215271,0.4569139778614044,0.4719080924987793,0.44694456458091736,0.6544302105903625,0.6480485200881958,0.4817052483558655,0.5333799123764038,0.4417027235031128,0.48973217606544495,0.3398161232471466,0.5329058170318604,0.6638816595077515,0.3701310157775879,0.5170656442642212,0.5042306780815125,0.37510615587234497,0.45437097549438477,0.5082879066467285,0.6491488814353943,0.4806847870349884,0.37062138319015503,0.5917735695838928,0.5042306780815125,0.4315448999404907,0.6918193101882935,0.559276282787323,0.3851678669452667,0.5137527585029602,0.3501840829849243,0.37010470032691956,0.6022205948829651,0.4678286910057068,0.4817052483558655,0.5141806602478027,0.3851678669452667,0.7539036870002747,0.3778100907802582,0.7212001085281372,0.44286635518074036,0.449211984872818,0.642375111579895,0.39300277829170227,0.40760180354118347,0.5737374424934387,0.5108885169029236,0.4340724050998688,0.5777632594108582,0.5982948541641235,0.5450772643089294,0.5137527585029602,0.5137527585029602,0.6865202188491821,0.46238744258880615,0.4088267385959625,0.6139060258865356,0.7328750491142273,0.4595737159252167,0.48524555563926697,0.49259307980537415,0.4984310269355774,0.406841903924942,0.39366021752357483,0.41609349846839905,0.5731421113014221,0.404873251914978,0.27873218059539795,0.5329345464706421,0.5089148879051208,0.37062138319015503,0.4680803418159485,0.5301138162612915,0.43026918172836304,0.5542822480201721,0.43859389424324036,0.5950580835342407,0.4678286910057068,0.42941024899482727,0.38653701543807983,0.5992511510848999,0.586916983127594,0.3833004832267761,0.6671711802482605,0.48216167092323303,0.42398563027381897,0.42 ...

# %%
# turn the prediction into an array
predictions_array = np.fromstring(predictions[1:], sep=',') 
predictions_array
# Out:
# array([0.60732621, 0.51731473, 0.34246418, ..., 0.51223242, 0.43407241,
#        0.52876359])
