# %% [markdown]
# ## Table of Contents
#
# ### 1. Text Generation using a pretrained DL model
# > #### 1.1 Install required libraries
# > #### 1.2 Define deep learning model
# > #### 1.3 Preprocess data and get prediction
#
# ---

# %% [markdown]
# ![Screenshot from 2021-02-28 17-26-13.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.1 Install required libraries

# %%
# installing huggingface's transfomers for using 
# pretrained model of text generation
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 1.9MB 5.5MB/s
#      |████████████████████████████████| 890kB 29.2MB/s
#      |████████████████████████████████| 3.2MB 44.2MB/s
#   Building wheel for sacremoses (setup.py) ... done

# %% [markdown]
# ### 1.2 Define deep learning model

# %%
# import required modules
from random import choice

from transformers import AutoTokenizer, AutoModelWithLMHead

# %%
# define pretrained text generation model
tokenizer = AutoTokenizer.from_pretrained("congcongwang/distilgpt2_fine_tuned_coder")
model = AutoModelWithLMHead.from_pretrained("congcongwang/distilgpt2_fine_tuned_coder")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=763.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898669.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=52.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=165.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=50.0, style=ProgressStyle(description_w…
# /usr/local/lib/python3.7/dist-packages/transformers/models/auto/modeling_auto.py:970: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   FutureWarning,
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=333969540.0, style=ProgressStyle(descri…

# %% [markdown]
# ### 1.3 Preprocess data and get prediction

# %%
# set the seed text
context = "def convert_to_num"

# preprocess seed text
input_ids = tokenizer.encode("<python> " + context, return_tensors='pt')

# generate output
outputs = model.generate(input_ids=input_ids,
                         max_length=512,     # max length of text generated 
                         temperature=0.7,    # variability of text
                         num_beams=2,        # ensure diversity in text
                         length_penalty=1.5) # give variability in text length 

# decode output to generate text
decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  def convert_to_num(self, char):
#         """
#         >>> hill_cipher = HillCipher(numpy.array([[2, 5], [1, 6]]))
#         >>> hill_cipher.decrypt('WHXYJOLM9C6XT085LL')
#         'TESTINGHILLCIPHERR'
#         >>> hill_cipher.decrypt('85FF00')
#         'HELLOO'
#         >>> hill_cipher.decrypt('85FF00')
#         'HELLOO'
#         """
#         self.decrypt_key = self.make_decrypt_key()
#         text = self.process_text(text.upper())
#         encrypted = ""
#
#         for i in range(0, len(self.

# %%
# set different seed texts
contexts = ["def fib", "def fact", "def sum_of_int", "def sum_of_fact", "def sum_of_squares", "def get_val", "def convert_to_num", "def get_date"]

# choose seed text
context = choice(contexts)

# preprocess seed text
input_ids = tokenizer.encode("<python> " + context, return_tensors='pt')

# generate output
outputs = model.generate(input_ids=input_ids,
                         max_length=512,
                         temperature=0.7,
                         num_return_sequences=1,
                         num_beams=2,
                         length_penalty=1.5)

# decode output to generate text
decoded = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(decoded)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#  def fibonacci_digits(self):
#         """
#         >>> Fibonacci(5).get(3)
#         [0, 1, 2, 3, 5]
#         [0, 1, 2, 3, 5]
#         """
#         return f"{self.__components} has {self.__components}"
#
#     def changeComponent(self, pos, value):
#         """
#            input: positive integer 'pos' > 0
#             changes the specified component (pos) with the
#            'value'
#         """
#         if pos < 0:
#             raise ValueError("pos cannot be negative.")
#         else:
